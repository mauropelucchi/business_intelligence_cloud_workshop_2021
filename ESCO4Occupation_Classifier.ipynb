# %% [markdown]
# # ESCO Occupation Classifier

# %% [markdown]
# Explore our dataset with SQL

# %%
# %sql
select * from default.esco_en_dataset_csv
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>title</th><th>idesco_level_4</th><th>esco_level_4</th></tr></thead><tbody><tr><td>B93-C04 Softwareentwickler C++ und C#/.NET (m/w)</td><td>2512</td><td>Software developers</td></tr><tr><td>Gezocht: Oracle Developer #Freelance #PandS #Jobs #Vacatures (Req:9096–Loc:Bxl)</td><td>2512</td><td>Software developers</td></tr><tr><td>Senior (GXP Process Excellence) Engineer</td><td>2512</td><td>Software developers</td></tr><tr><td>Software-Entwickler (m/w/d) Buildsystem / Integration</td><td>2512</td><td>Software developers</td></tr><tr><td>Business Intelligence Developer</td><td>2512</td><td>Software developers</td></tr><tr><td>Microsoft Dynamics NAV Functional Consultant</td><td>2512</td><td>Software developers</td></tr><tr><td>Senior Ecotoxicological Expert</td><td>2512</td><td>Software developers</td></tr><tr><td>Senior Physical Layer Software Engineer - 729984</td><td>2512</td><td>Software developers</td></tr><tr><td>Junior of Senior Inkoper</td><td>2512</td><td>Software developers</td></tr><tr><td>Software Engineer .Net (SE01)</td><td>2512</td><td>Software developers</td></tr><tr><td>ABAP Developer - Industry (m/f/d)</td><td>2512</td><td>Software developers</td></tr><tr><td>Data Developer / Engineer Linux Python ETL</td><td>2512</td><td>Software developers</td></tr><tr><td>Senior UI & Workflow Developer with Activiti</td><td>2512</td><td>Software developers</td></tr><tr><td>Software Developer - Graduate Programme</td><td>2512</td><td>Software developers</td></tr><tr><td>1 Architecte D’interieur Charge De Clientele (m/f)</td><td>2512</td><td>Software developers</td></tr><tr><td>(Senior)-Betriebsleiter (m/w)</td><td>2512</td><td>Software developers</td></tr><tr><td>Architect - Award-Winning & Chartered Practice</td><td>2512</td><td>Software developers</td></tr><tr><td>Senior eDiscovery and Digital Forensics Consultant - Dublin</td><td>2512</td><td>Software developers</td></tr><tr><td>IAM developer</td><td>2512</td><td>Software developers</td></tr><tr><td>Software Engineer C/C++ (m/w)</td><td>2512</td><td>Software developers</td></tr><tr><td>Senior Software Engineer in Quality</td><td>2512</td><td>Software developers</td></tr><tr><td>.NET C# developer with SCRUM</td><td>2512</td><td>Software developers</td></tr><tr><td>C# Developer</td><td>2512</td><td>Software developers</td></tr><tr><td>Software Developer BRM</td><td>2512</td><td>Software developers</td></tr><tr><td>C# .NET Developer (Contract)</td><td>2512</td><td>Software developers</td></tr><tr><td>SAP ABAP DEVELOPER</td><td>2512</td><td>Software developers</td></tr><tr><td>Werkstudent Finance (m/w/d)</td><td>2512</td><td>Software developers</td></tr><tr><td>Prozessmanager Microsoft Dynamics NAV (m/w)</td><td>2512</td><td>Software developers</td></tr><tr><td>SW-EntwicklerIn (Full-Stack) Python / Javascript</td><td>2512</td><td>Software developers</td></tr><tr><td>=  Java Software Development Engineer SL3  =</td><td>2512</td><td>Software developers</td></tr><tr><td>Senior Java Developer - Canary Wharf - Up to £80k</td><td>2512</td><td>Software developers</td></tr><tr><td>Java / PHP Developer</td><td>2512</td><td>Software developers</td></tr><tr><td>Senior Technician – Equipment Services Radiotherapy Physics</td><td>2512</td><td>Software developers</td></tr><tr><td>Software Engineer III - Clonakilty</td><td>2512</td><td>Software developers</td></tr><tr><td>Softwareentwickler (m/w) Oracle</td><td>2512</td><td>Software developers</td></tr><tr><td>Junior Back-end Developer</td><td>2512</td><td>Software developers</td></tr><tr><td>Sponsorship Executive (P/T - 4 days a week)</td><td>2512</td><td>Software developers</td></tr><tr><td>Senior Expert Inertial Sensors (IMU) for "Digital Rail Germany" (f/m/d)</td><td>2512</td><td>Software developers</td></tr><tr><td>Android Developer</td><td>2512</td><td>Software developers</td></tr><tr><td>Angular-5 Software Developer</td>< ...

# %% [markdown]
# Now check the distribution of ESCO OCCUPATION in the dataset

# %%
# %sql
select esco_level_4, count(*) from default.esco_en_dataset_csv group by esco_level_4
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>esco_level_4</th><th>count(1)</th></tr></thead><tbody><tr><td>Advertising and marketing professionals</td><td>5000</td></tr><tr><td>Software developers</td><td>5000</td></tr><tr><td>Mathematicians, actuaries and statisticians</td><td>5000</td></tr><tr><td>Industrial and production engineers</td><td>5000</td></tr></tbody></table></div>

# %% [markdown]
# Read data from database (lowercase, alias, ...)

# %%
dataset = spark.sql("select regexp_replace(lower(title), '[0-9]', ' ') as title_cleaned,title,idesco_level_4 as target, esco_level_4 as target_label from default.esco_en_dataset_csv")
display(dataset.select("*"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>title_cleaned</th><th>title</th><th>target</th><th>target_label</th></tr></thead><tbody><tr><td>b  -c   softwareentwickler c++ und c#/.net (m/w)</td><td>B93-C04 Softwareentwickler C++ und C#/.NET (m/w)</td><td>2512</td><td>Software developers</td></tr><tr><td>gezocht: oracle developer #freelance #pands #jobs #vacatures (req:    –loc:bxl)</td><td>Gezocht: Oracle Developer #Freelance #PandS #Jobs #Vacatures (Req:9096–Loc:Bxl)</td><td>2512</td><td>Software developers</td></tr><tr><td>senior (gxp process excellence) engineer</td><td>Senior (GXP Process Excellence) Engineer</td><td>2512</td><td>Software developers</td></tr><tr><td>software-entwickler (m/w/d) buildsystem / integration</td><td>Software-Entwickler (m/w/d) Buildsystem / Integration</td><td>2512</td><td>Software developers</td></tr><tr><td>business intelligence developer</td><td>Business Intelligence Developer</td><td>2512</td><td>Software developers</td></tr><tr><td>microsoft dynamics nav functional consultant</td><td>Microsoft Dynamics NAV Functional Consultant</td><td>2512</td><td>Software developers</td></tr><tr><td>senior ecotoxicological expert</td><td>Senior Ecotoxicological Expert</td><td>2512</td><td>Software developers</td></tr><tr><td>senior physical layer software engineer -       </td><td>Senior Physical Layer Software Engineer - 729984</td><td>2512</td><td>Software developers</td></tr><tr><td>junior of senior inkoper</td><td>Junior of Senior Inkoper</td><td>2512</td><td>Software developers</td></tr><tr><td>software engineer .net (se  )</td><td>Software Engineer .Net (SE01)</td><td>2512</td><td>Software developers</td></tr><tr><td>abap developer - industry (m/f/d)</td><td>ABAP Developer - Industry (m/f/d)</td><td>2512</td><td>Software developers</td></tr><tr><td>data developer / engineer linux python etl</td><td>Data Developer / Engineer Linux Python ETL</td><td>2512</td><td>Software developers</td></tr><tr><td>senior ui & workflow developer with activiti</td><td>Senior UI & Workflow Developer with Activiti</td><td>2512</td><td>Software developers</td></tr><tr><td>software developer - graduate programme</td><td>Software Developer - Graduate Programme</td><td>2512</td><td>Software developers</td></tr><tr><td>  architecte d’interieur charge de clientele (m/f)</td><td>1 Architecte D’interieur Charge De Clientele (m/f)</td><td>2512</td><td>Software developers</td></tr><tr><td>(senior)-betriebsleiter (m/w)</td><td>(Senior)-Betriebsleiter (m/w)</td><td>2512</td><td>Software developers</td></tr><tr><td>architect - award-winning & chartered practice</td><td>Architect - Award-Winning & Chartered Practice</td><td>2512</td><td>Software developers</td></tr><tr><td>senior ediscovery and digital forensics consultant - dublin</td><td>Senior eDiscovery and Digital Forensics Consultant - Dublin</td><td>2512</td><td>Software developers</td></tr><tr><td>iam developer</td><td>IAM developer</td><td>2512</td><td>Software developers</td></tr><tr><td>software engineer c/c++ (m/w)</td><td>Software Engineer C/C++ (m/w)</td><td>2512</td><td>Software developers</td></tr><tr><td>senior software engineer in quality</td><td>Senior Software Engineer in Quality</td><td>2512</td><td>Software developers</td></tr><tr><td>.net c# developer with scrum</td><td>.NET C# developer with SCRUM</td><td>2512</td><td>Software developers</td></tr><tr><td>c# developer</td><td>C# Developer</td><td>2512</td><td>Software developers</td></tr><tr><td>software developer brm</td><td>Software Developer BRM</td><td>2512</td><td>Software developers</td></tr><tr><td>c# .net developer (contract)</td><td>C# .NET Developer (Contract)</td><td>2512</td><td>Software developers</td></tr><tr><td>sap abap developer</td><td>SAP ABAP DEVELOPER</td><td>2512</td><td>Software developers</td></tr><tr><td>werkstudent finance (m/w/d)</td><td>Werkstudent Finance (m/w/d)</td><td>2512</td><td>Software developers</td></ ...

# %% [markdown]
# ### Pre-processing (clean text and reduce features)

# %%
from pyspark.ml.feature import RegexTokenizer
from pyspark.sql.functions import col, udf
from pyspark.sql.types import IntegerType

regexTokenizer = RegexTokenizer(inputCol="title_cleaned", outputCol="words", pattern="\\W")
# alternatively, pattern="\\w+", gaps(False)

countTokens = udf(lambda words: len(words), IntegerType())

tokenized = regexTokenizer.transform(dataset)
tokenized.select("title_cleaned", "words").withColumn("tokens", countTokens(col("words"))).show(truncate=False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------------------------------------------------------------------------+------------------------------------------------------------------------------+------+
# title_cleaned                                                                  |words                                                                         |tokens|
# +-------------------------------------------------------------------------------+------------------------------------------------------------------------------+------+
# b  -c   softwareentwickler c++ und c#/.net (m/w)                               |[b, c, softwareentwickler, c, und, c, net, m, w]                              |9     |
# gezocht: oracle developer #freelance #pands #jobs #vacatures (req:    –loc:bxl)|[gezocht, oracle, developer, freelance, pands, jobs, vacatures, req, loc, bxl]|10    |
# senior (gxp process excellence) engineer                                       |[senior, gxp, process, excellence, engineer]                                  |5     |
# software-entwickler (m/w/d) buildsystem / integration                          |[software, entwickler, m, w, d, buildsystem, integration]                     |7     |
# business intelligence developer                                                |[business, intelligence, developer]                                           |3     |
# microsoft dynamics nav functional consultant                                   |[microsoft, dynamics, nav, functional, consultant]                            |5     |
# senior ecotoxicological expert                                                 |[senior, ecotoxicological, expert]                                            |3     |
# senior physical layer software engineer -                                      |[senior, physical, layer, software, engineer]                                 |5     |
# junior of senior inkoper                                                       |[junior, of, senior, inkoper]                                                 |4     |
# software engineer .net (se  )                                                  |[software, engineer, net, se]                                                 |4     |
# abap developer - industry (m/f/d)                                              |[abap, developer, industry, m, f, d]                                          |6     |
# data developer / engineer linux python etl                                     |[data, developer, engineer, linux, python, etl]                               |6     |
# senior ui &amp; workflow developer with activiti                                   |[senior, ui, workflow, developer, with, activiti]                             |6     |
# software developer - graduate programme                                        |[software, developer, graduate, programme]                                    |4     |
#   architecte d’interieur charge de clientele (m/f)                             |[architecte, d, interieur, charge, de, clientele, m, f]                       |8     |
# (senior)-betriebsleiter (m/w)                                                  |[senior, betriebsleiter, m, w]                                                |4     |
# architect - award-winning &amp; chartered practice                                 |[architect, award, winning, chartered, practice]                              |5     |
# senior ediscovery and digital forensics consultant - dublin                    |[senior, ediscovery, and, digital, forensics, consultant, dublin]             |7     |
# iam developer                                                                  |[iam, developer]                                                              |2     |
# software engineer c/c++ (m/w)                                                  |[software, engineer, c, c, m, w]                                              |6     |
# +-------------------------------------------------------------------------------+------------------------------------------------------------------------------+------+
# only showing top 20 rows
#
# </div>

# %%
from pyspark.sql.functions import explode, desc
tokens = tokenized.select(explode(col("words")).alias("word")).groupBy(col("word")).count().orderBy(desc("count"))
tokens.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+-----+
#        word|count|
# +-----------+-----+
#           m| 4895|
#           w| 3522|
#    engineer| 2699|
#      senior| 2698|
#           f| 2686|
#     manager| 2071|
#   marketing| 2060|
#   developer| 1813|
#    business| 1506|
#          in| 1497|
#    software| 1305|
#  consultant| 1285|
#           h| 1161|
# development| 1102|
#     analyst| 1021|
#           d|  890|
#   analytics|  805|
#         and|  795|
#      supply|  793|
#       chain|  772|
# +-----------+-----+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# We have to filter shor sentences, stopwords, ...

# %% [markdown]
# Start short string (len < 3) with a user defined funtion

# %%
from pyspark.sql.functions import udf
from pyspark.sql.types import ArrayType, StringType
def filter_by_len(words):
  filtered = [word for word in words if len(word) >= 3]
  return filtered

filter_by_len_udf = udf(filter_by_len, ArrayType(StringType()))

filtered = tokenized.withColumn("filtered", filter_by_len_udf(col("words")))
filtered.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+--------------------+------+-------------------+--------------------+--------------------+
#        title_cleaned|               title|target|       target_label|               words|            filtered|
# +--------------------+--------------------+------+-------------------+--------------------+--------------------+
# b  -c   softwaree...|B93-C04 Softwaree...|  2512|Software developers|[b, c, softwareen...|[softwareentwickl...|
# gezocht: oracle d...|Gezocht: Oracle D...|  2512|Software developers|[gezocht, oracle,...|[gezocht, oracle,...|
# senior (gxp proce...|Senior (GXP Proce...|  2512|Software developers|[senior, gxp, pro...|[senior, gxp, pro...|
# software-entwickl...|Software-Entwickl...|  2512|Software developers|[software, entwic...|[software, entwic...|
# business intellig...|Business Intellig...|  2512|Software developers|[business, intell...|[business, intell...|
# microsoft dynamic...|Microsoft Dynamic...|  2512|Software developers|[microsoft, dynam...|[microsoft, dynam...|
# senior ecotoxicol...|Senior Ecotoxicol...|  2512|Software developers|[senior, ecotoxic...|[senior, ecotoxic...|
# senior physical l...|Senior Physical L...|  2512|Software developers|[senior, physical...|[senior, physical...|
# junior of senior ...|Junior of Senior ...|  2512|Software developers|[junior, of, seni...|[junior, senior, ...|
# software engineer...|Software Engineer...|  2512|Software developers|[software, engine...|[software, engine...|
# abap developer - ...|ABAP Developer - ...|  2512|Software developers|[abap, developer,...|[abap, developer,...|
# data developer / ...|Data Developer / ...|  2512|Software developers|[data, developer,...|[data, developer,...|
# senior ui &amp; workf...|Senior UI &amp; Workf...|  2512|Software developers|[senior, ui, work...|[senior, workflow...|
# software develope...|Software Develope...|  2512|Software developers|[software, develo...|[software, develo...|
#   architecte d’in...|1 Architecte D’in...|  2512|Software developers|[architecte, d, i...|[architecte, inte...|
# (senior)-betriebs...|(Senior)-Betriebs...|  2512|Software developers|[senior, betriebs...|[senior, betriebs...|
# architect - award...|Architect - Award...|  2512|Software developers|[architect, award...|[architect, award...|
# senior ediscovery...|Senior eDiscovery...|  2512|Software developers|[senior, ediscove...|[senior, ediscove...|
#        iam developer|       IAM developer|  2512|Software developers|    [iam, developer]|    [iam, developer]|
# software engineer...|Software Engineer...|  2512|Software developers|[software, engine...|[software, engineer]|
# +--------------------+--------------------+------+-------------------+--------------------+--------------------+
# only showing top 20 rows
#
# </div>

# %%
filtered.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- title_cleaned: string (nullable = true)
# -- title: string (nullable = true)
# -- target: string (nullable = true)
# -- target_label: string (nullable = true)
# -- words: array (nullable = true)
#     |-- element: string (containsNull = true)
# -- filtered: array (nullable = true)
#     |-- element: string (containsNull = true)
#
# </div>

# %%
tokens = filtered.select(explode(col("filtered")).alias("word")).groupBy(col("word")).count().orderBy(desc("count"))
tokens.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+-----+
#        word|count|
# +-----------+-----+
#    engineer| 2699|
#      senior| 2698|
#     manager| 2071|
#   marketing| 2060|
#   developer| 1813|
#    business| 1506|
#    software| 1305|
#  consultant| 1285|
# development| 1102|
#     analyst| 1021|
#   analytics|  805|
#         and|  795|
#      supply|  793|
#       chain|  772|
#  specialist|  732|
#     actuary|  682|
#   actuarial|  677|
#        java|  573|
#         job|  573|
#      junior|  540|
# +-----------+-----+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# Now we remove the stopwords...

# %%
from pyspark.ml.feature import StopWordsRemover


remover = StopWordsRemover(inputCol="filtered", outputCol="cleaned")
cleaned = remover.transform(filtered)
cleaned.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+--------------------+------+-------------------+--------------------+--------------------+--------------------+
#        title_cleaned|               title|target|       target_label|               words|            filtered|             cleaned|
# +--------------------+--------------------+------+-------------------+--------------------+--------------------+--------------------+
# b  -c   softwaree...|B93-C04 Softwaree...|  2512|Software developers|[b, c, softwareen...|[softwareentwickl...|[softwareentwickl...|
# gezocht: oracle d...|Gezocht: Oracle D...|  2512|Software developers|[gezocht, oracle,...|[gezocht, oracle,...|[gezocht, oracle,...|
# senior (gxp proce...|Senior (GXP Proce...|  2512|Software developers|[senior, gxp, pro...|[senior, gxp, pro...|[senior, gxp, pro...|
# software-entwickl...|Software-Entwickl...|  2512|Software developers|[software, entwic...|[software, entwic...|[software, entwic...|
# business intellig...|Business Intellig...|  2512|Software developers|[business, intell...|[business, intell...|[business, intell...|
# microsoft dynamic...|Microsoft Dynamic...|  2512|Software developers|[microsoft, dynam...|[microsoft, dynam...|[microsoft, dynam...|
# senior ecotoxicol...|Senior Ecotoxicol...|  2512|Software developers|[senior, ecotoxic...|[senior, ecotoxic...|[senior, ecotoxic...|
# senior physical l...|Senior Physical L...|  2512|Software developers|[senior, physical...|[senior, physical...|[senior, physical...|
# junior of senior ...|Junior of Senior ...|  2512|Software developers|[junior, of, seni...|[junior, senior, ...|[junior, senior, ...|
# software engineer...|Software Engineer...|  2512|Software developers|[software, engine...|[software, engine...|[software, engine...|
# abap developer - ...|ABAP Developer - ...|  2512|Software developers|[abap, developer,...|[abap, developer,...|[abap, developer,...|
# data developer / ...|Data Developer / ...|  2512|Software developers|[data, developer,...|[data, developer,...|[data, developer,...|
# senior ui &amp; workf...|Senior UI &amp; Workf...|  2512|Software developers|[senior, ui, work...|[senior, workflow...|[senior, workflow...|
# software develope...|Software Develope...|  2512|Software developers|[software, develo...|[software, develo...|[software, develo...|
#   architecte d’in...|1 Architecte D’in...|  2512|Software developers|[architecte, d, i...|[architecte, inte...|[architecte, inte...|
# (senior)-betriebs...|(Senior)-Betriebs...|  2512|Software developers|[senior, betriebs...|[senior, betriebs...|[senior, betriebs...|
# architect - award...|Architect - Award...|  2512|Software developers|[architect, award...|[architect, award...|[architect, award...|
# senior ediscovery...|Senior eDiscovery...|  2512|Software developers|[senior, ediscove...|[senior, ediscove...|[senior, ediscove...|
#        iam developer|       IAM developer|  2512|Software developers|    [iam, developer]|    [iam, developer]|    [iam, developer]|
# software engineer...|Software Engineer...|  2512|Software developers|[software, engine...|[software, engineer]|[software, engineer]|
# +--------------------+--------------------+------+-------------------+--------------------+--------------------+--------------------+
# only showing top 20 rows
#
# </div>

# %%
tokens = cleaned.select(explode(col("cleaned")).alias("word")).groupBy(col("word")).count().orderBy(desc("count"))
tokens.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+-----+
#        word|count|
# +-----------+-----+
#    engineer| 2699|
#      senior| 2698|
#     manager| 2071|
#   marketing| 2060|
#   developer| 1813|
#    business| 1506|
#    software| 1305|
#  consultant| 1285|
# development| 1102|
#     analyst| 1021|
#   analytics|  805|
#      supply|  793|
#       chain|  772|
#  specialist|  732|
#     actuary|  682|
#   actuarial|  677|
#        java|  573|
#         job|  573|
#      junior|  540|
#  technology|  508|
# +-----------+-----+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# N-grams creation....

# %%
from pyspark.ml.feature import NGram
ngrams2 = NGram(n=2, inputCol="cleaned", outputCol="ngrams_2")
ngrams3 = NGram(n=3, inputCol="cleaned", outputCol="ngrams_3")
ngrams4 = NGram(n=4, inputCol="cleaned", outputCol="ngrams_4")


ngrams = ngrams2.transform(cleaned)
ngrams = ngrams3.transform(ngrams)
ngrams = ngrams4.transform(ngrams)






ngrams.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+--------------------+------+-------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
#        title_cleaned|               title|target|       target_label|               words|            filtered|             cleaned|            ngrams_2|            ngrams_3|            ngrams_4|
# +--------------------+--------------------+------+-------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# b  -c   softwaree...|B93-C04 Softwaree...|  2512|Software developers|[b, c, softwareen...|[softwareentwickl...|[softwareentwickl...|[softwareentwickl...|[softwareentwickl...|                  []|
# gezocht: oracle d...|Gezocht: Oracle D...|  2512|Software developers|[gezocht, oracle,...|[gezocht, oracle,...|[gezocht, oracle,...|[gezocht oracle, ...|[gezocht oracle d...|[gezocht oracle d...|
# senior (gxp proce...|Senior (GXP Proce...|  2512|Software developers|[senior, gxp, pro...|[senior, gxp, pro...|[senior, gxp, pro...|[senior gxp, gxp ...|[senior gxp proce...|[senior gxp proce...|
# software-entwickl...|Software-Entwickl...|  2512|Software developers|[software, entwic...|[software, entwic...|[software, entwic...|[software entwick...|[software entwick...|[software entwick...|
# business intellig...|Business Intellig...|  2512|Software developers|[business, intell...|[business, intell...|[business, intell...|[business intelli...|[business intelli...|                  []|
# microsoft dynamic...|Microsoft Dynamic...|  2512|Software developers|[microsoft, dynam...|[microsoft, dynam...|[microsoft, dynam...|[microsoft dynami...|[microsoft dynami...|[microsoft dynami...|
# senior ecotoxicol...|Senior Ecotoxicol...|  2512|Software developers|[senior, ecotoxic...|[senior, ecotoxic...|[senior, ecotoxic...|[senior ecotoxico...|[senior ecotoxico...|                  []|
# senior physical l...|Senior Physical L...|  2512|Software developers|[senior, physical...|[senior, physical...|[senior, physical...|[senior physical,...|[senior physical ...|[senior physical ...|
# junior of senior ...|Junior of Senior ...|  2512|Software developers|[junior, of, seni...|[junior, senior, ...|[junior, senior, ...|[junior senior, s...|[junior senior in...|                  []|
# software engineer...|Software Engineer...|  2512|Software developers|[software, engine...|[software, engine...|[software, engine...|[software enginee...|[software enginee...|                  []|
# abap developer - ...|ABAP Developer - ...|  2512|Software developers|[abap, developer,...|[abap, developer,...|[abap, developer,...|[abap developer, ...|[abap developer i...|                  []|
# data developer / ...|Data Developer / ...|  2512|Software developers|[data, developer,...|[data, developer,...|[data, developer,...|[data developer, ...|[data developer e...|[data developer e...|
# senior ui &amp; workf...|Senior UI &amp; Workf...|  2512|Software developers|[senior, ui, work...|[senior, workflow...|[senior, workflow...|[senior workflow,...|[senior workflow ...|[senior workflow ...|
# software develope...|Software Develope...|  2512|Software developers|[software, develo...|[software, develo...|[software, develo...|[software develop...|[software develop...|[software develop...|
#   architecte d’in...|1 Architecte D’in...|  2512|Software developers|[architecte, d, i...|[architecte, inte...|[architecte, inte...|[architecte inter...|[architecte inter...|[architecte inter...|
# (senior)-betriebs...|(Senior)-Betriebs...|  2512|Software developers|[senior, betriebs...|[senior, betriebs...|[senior, betriebs...|[senior betriebsl...|                  []|                  []|
# architect - award...|Architect - Award...|  2512|Software developers|[architect, award...|[architect, award...|[architect, award...|[architect award,...|[architect award ...|[architect award ...|
# senior ediscovery...|Senior eDiscovery...|  2512|Software developers|[senior, ediscove...|[senior, ediscove...|[senior, ediscove...|[senior ediscover...|[senior ediscover...|[senior ediscover...|
#        iam developer|       IAM developer|  2512|Software developers|    [iam, developer]|    [iam, developer]|    [iam, developer]|     [iam developer]|                  []|                  []|
# software engineer...|Software Engineer...|  2512|Software developers|[software, engine...|[software, engineer]|[software, engineer]| [software engineer]|                  []|                  []|
# +--------------------+--------------------+------+-------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# only showing top 20 rows
#
# </div>

# %%
# union of the results

def union_ngrams(c1,c2,c3,c4):
  return c1 + c2 + c3 + c4

union_ngrams_udf = udf(union_ngrams, ArrayType(StringType()))

ngrams_final = ngrams.filter("cleaned is not Null").withColumn("ngrams", union_ngrams_udf(col("cleaned"), col("ngrams_2"), col("ngrams_3"), col("ngrams_4")))
ngrams_final.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+--------------------+------+-------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
#        title_cleaned|               title|target|       target_label|               words|            filtered|             cleaned|            ngrams_2|            ngrams_3|            ngrams_4|              ngrams|
# +--------------------+--------------------+------+-------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# b  -c   softwaree...|B93-C04 Softwaree...|  2512|Software developers|[b, c, softwareen...|[softwareentwickl...|[softwareentwickl...|[softwareentwickl...|[softwareentwickl...|                  []|[softwareentwickl...|
# gezocht: oracle d...|Gezocht: Oracle D...|  2512|Software developers|[gezocht, oracle,...|[gezocht, oracle,...|[gezocht, oracle,...|[gezocht oracle, ...|[gezocht oracle d...|[gezocht oracle d...|[gezocht, oracle,...|
# senior (gxp proce...|Senior (GXP Proce...|  2512|Software developers|[senior, gxp, pro...|[senior, gxp, pro...|[senior, gxp, pro...|[senior gxp, gxp ...|[senior gxp proce...|[senior gxp proce...|[senior, gxp, pro...|
# software-entwickl...|Software-Entwickl...|  2512|Software developers|[software, entwic...|[software, entwic...|[software, entwic...|[software entwick...|[software entwick...|[software entwick...|[software, entwic...|
# business intellig...|Business Intellig...|  2512|Software developers|[business, intell...|[business, intell...|[business, intell...|[business intelli...|[business intelli...|                  []|[business, intell...|
# microsoft dynamic...|Microsoft Dynamic...|  2512|Software developers|[microsoft, dynam...|[microsoft, dynam...|[microsoft, dynam...|[microsoft dynami...|[microsoft dynami...|[microsoft dynami...|[microsoft, dynam...|
# senior ecotoxicol...|Senior Ecotoxicol...|  2512|Software developers|[senior, ecotoxic...|[senior, ecotoxic...|[senior, ecotoxic...|[senior ecotoxico...|[senior ecotoxico...|                  []|[senior, ecotoxic...|
# senior physical l...|Senior Physical L...|  2512|Software developers|[senior, physical...|[senior, physical...|[senior, physical...|[senior physical,...|[senior physical ...|[senior physical ...|[senior, physical...|
# junior of senior ...|Junior of Senior ...|  2512|Software developers|[junior, of, seni...|[junior, senior, ...|[junior, senior, ...|[junior senior, s...|[junior senior in...|                  []|[junior, senior, ...|
# software engineer...|Software Engineer...|  2512|Software developers|[software, engine...|[software, engine...|[software, engine...|[software enginee...|[software enginee...|                  []|[software, engine...|
# abap developer - ...|ABAP Developer - ...|  2512|Software developers|[abap, developer,...|[abap, developer,...|[abap, developer,...|[abap developer, ...|[abap developer i...|                  []|[abap, developer,...|
# data developer / ...|Data Developer / ...|  2512|Software developers|[data, developer,...|[data, developer,...|[data, developer,...|[data developer, ...|[data developer e...|[data developer e...|[data, developer,...|
# senior ui &amp; workf...|Senior UI &amp; Workf...|  2512|Software developers|[senior, ui, work...|[senior, workflow...|[senior, workflow...|[senior workflow,...|[senior workflow ...|[senior workflow ...|[senior, workflow...|
# software develope...|Software Develope...|  2512|Software developers|[software, develo...|[software, develo...|[software, develo...|[software develop...|[software develop...|[software develop...|[software, develo...|
#   architecte d’in...|1 Architecte D’in...|  2512|Software developers|[architecte, d, i...|[architecte, inte...|[architecte, inte...|[architecte inter...|[architecte inter...|[architecte inter...|[architecte, inte...|
# (senior)-betriebs...|(Senior)-Betriebs...|  2512|Software developers|[senior, betriebs...|[senior, betriebs...|[senior, betriebs...|[senior betriebsl...|                  []|                  []|[senior, betriebs...|
# architect - award...|Architect - Award...|  2512|Software developers|[architect, award...|[architect, award...|[architect, award...|[architect award,...|[architect award ...|[architect award ...|[architect, award...|
# senior ediscovery...|Senior eDiscovery...|  2512|Software developers|[senior, ediscove...|[senior, ediscove...|[senior, ediscove...|[senior ediscover...|[senior ediscover...|[senior ediscover...|[senior, ediscove...|
#        iam developer|       IAM developer|  2512|Software developers|    [iam, developer]|    [iam, developer]|    [iam, developer]|     [iam developer]|                  []|                  []|[iam, developer, ...|
# software engineer...|Software Engineer...|  2512|Software developers|[software, engine...|[software, engineer]|[software, engineer]| [software engineer]|                  []|                  []|[software, engine...|
# +--------------------+--------------------+------+-------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# Train a Word2Vec model...

# %%
from pyspark.ml.feature import Word2Vec

word2Vec = Word2Vec(vectorSize=300, minCount=10, inputCol="ngrams", outputCol="features")
model = word2Vec.fit(ngrams_final)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Try our model

# %%
model.findSynonyms("java", 10).show(truncate=False)
model.findSynonyms("senior developer", 10).show(truncate=False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------------+------------------+
# word                   |similarity        |
# +-----------------------+------------------+
# jee                    |0.9291090369224548|
# php                    |0.9272879958152771|
# senior java            |0.9127849340438843|
# scala                  |0.9039961099624634|
# softwareentwickler java|0.9014872312545776|
# java backend           |0.8995242118835449|
# backend                |0.8989054560661316|
# junior senior          |0.8958484530448914|
# java entwickler        |0.8927369117736816|
# front                  |0.8908916115760803|
# +-----------------------+------------------+
#
# +------------------+------------------+
# word              |similarity        |
# +------------------+------------------+
# developer contract|0.976405918598175 |
# python developer  |0.9719674587249756|
# developer junior  |0.9676873683929443|
# senior php        |0.9660688042640686|
# stack net         |0.9643912315368652|
# developer senior  |0.9621933102607727|
# junior senior     |0.9615448713302612|
# react             |0.9605578780174255|
# senior full       |0.9584881663322449|
# sitecore          |0.9570395946502686|
# +------------------+------------------+
#
# </div>

# %% [markdown]
# Now apply our model to the data...

# %%
from pyspark.ml.feature import MinMaxScaler
from pyspark.ml.linalg import Vectors

ngrams_featured = model.transform(ngrams_final)
scaler = MinMaxScaler(inputCol="features", outputCol="scaledFeatures")
scalerModel = scaler.fit(ngrams_featured)
scaledData = scalerModel.transform(ngrams_featured)
print("Features scaled to range: [%f, %f]" % (scaler.getMin(), scaler.getMax()))
scaledData.select("features", "scaledFeatures").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Features scaled to range: [0.000000, 1.000000]
# +--------------------+--------------------+
#             features|      scaledFeatures|
# +--------------------+--------------------+
# [-0.0247547167818...|[0.32806994067062...|
# [-0.0044489827226...|[0.36888785079528...|
# [-6.8516994724632...|[0.37645374184569...|
# [-0.0425977274775...|[0.29220251500641...|
# [-0.0267910513405...|[0.32397656878078...|
# [-0.0033392063840...|[0.37111868621901...|
# [0.02218511731674...|[0.42242683138490...|
# [-0.0143434144556...|[0.34899839375647...|
# [0.03063876507803...|[0.43942007248314...|
# [-0.0730727768968...|[0.23094258593360...|
# [-0.0225463698928...|[0.33250908601636...|
# [-0.0053536206283...|[0.36706937781503...|
# [0.00419105067849...|[0.38625575809728...|
# [-0.0286015445832...|[0.32033717558068...|
# [-0.0028299268800...|[0.37214242291145...|
# [0.04968292017777...|[0.47770199861257...|
# [-0.0032001979915...|[0.37139811625874...|
# [0.02138290373194...|[0.42081424836232...|
# [-0.0357127512494...|[0.30604246484854...|
# [-0.1166188543041...|[0.14340771185801...|
# +--------------------+--------------------+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# Convert target label to index

# %%
from pyspark.ml.feature import IndexToString, StringIndexer

indexer = StringIndexer(inputCol="target", outputCol="label")
indexer_model = indexer.fit(scaledData)
indexed = indexer_model.transform(scaledData)

converter = IndexToString(inputCol="prediction", outputCol="prediction_category", labels=indexer_model.labels)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Prepare train and test

# %%
from pyspark.ml.classification import NaiveBayes
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.tuning import ParamGridBuilder, TrainValidationSplit

train, test = indexed.randomSplit([0.8, 0.2], seed=12345)

nb = NaiveBayes(smoothing=1.0, modelType="multinomial", labelCol="label", featuresCol="scaledFeatures")
paramGrid = ParamGridBuilder()\
    .addGrid(nb.smoothing, [0.1, 0.5, 1.0]) \
    .build()

tvs = TrainValidationSplit(estimator=nb,
                           estimatorParamMaps=paramGrid,
                           evaluator=MulticlassClassificationEvaluator(),
                           trainRatio=0.8)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
model = tvs.fit(train)
predictions = model.transform(test).select("title", "label", "prediction")
predictions.show(truncate=False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/spark/python/pyspark/ml/util.py:762: UserWarning: Cannot find mlflow module. To enable MLflow logging, install mlflow from PyPI.
#   warnings.warn(_MLflowInstrumentation._NO_MLFLOW_WARNING)
# +----------------------------------------------------------------------------------------------+-----+----------+
# title                                                                                         |label|prediction|
# +----------------------------------------------------------------------------------------------+-----+----------+
# 3157094_Consultant (w/m) Actuarial Services/EMEIA Financia                                    |0.0  |0.0       |
# 2018 Intern - Mechanical/Manufacturing Engineer 1                                             |1.0  |1.0       |
# 2015 Internships – Physical IP / Implementation / Standard Cell/ Memory / Software Development|3.0  |3.0       |
# 1283 Mathematician-Math programmer                                                            |0.0  |0.0       |
# 2641-15 Betriebsingenieur (m/w) - Ravensburg                                                  |1.0  |0.0       |
# 211-0050/18-2H PhD stipends in Statistics and the mathematics of Insurance and Economics      |0.0  |0.0       |
# 840D Inbetriebnehmer                                                                          |1.0  |3.0       |
# 1 Marie Curie PhD fellows in Computer Science                                                 |3.0  |0.0       |
# 5G Test Tool Developer ( 240365 )                                                             |3.0  |3.0       |
#  Marketing Assistant; Sport,Sales, Fitness, Leadership                                        |2.0  |2.0       |
#  Unity Game Developer                                                                         |0.0  |3.0       |
# (Business) Mathematician (temporary)                                                          |0.0  |2.0       |
# (Business) Mathematician / Pricing Actuary (temporary)                                        |0.0  |0.0       |
# (CONTRACT) 5G Standardization Algorithm Engineer (PHY/MAC)                                    |0.0  |3.0       |
# (Economic) Mathematician (temporary)                                                          |0.0  |0.0       |
# (Ett) It Software Developer                                                                   |3.0  |3.0       |
# (Gas- Wasserinstallateure, Anlagenmechaniker HLKS)                                            |1.0  |0.0       |
# (Inhouse) Developer ABAP / ABAP OO (m/w)                                                      |3.0  |3.0       |
# (Inhouse) Softwareentwickler SAP ABAP (m/w)                                                   |3.0  |3.0       |
# (interim) Internet Marketeer                                                                  |2.0  |2.0       |
# +----------------------------------------------------------------------------------------------+-----+----------+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# Compute accuracy on the test set

# %%
evaluator = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction",
                                              metricName="weightedPrecision")
precision = evaluator.evaluate(predictions)
print("Test set weighted precision = " + str(precision))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Test set weighted precision = 0.759777484369929
# </div>
